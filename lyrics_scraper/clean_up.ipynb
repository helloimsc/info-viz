# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from lyrics import scrape_lyrics

# %%
df = pd.read_csv("../data/lyrics_25200.csv")

# %%
df = df.reset_index()

# %%
df.head()
# Out:
#    index  Unnamed: 0              spotify_id  daily_rank  popularity  \
# 0      0           0  65UgeS6VdIpUQqR3UoGw9j        48.0        54.0
# 1      1           1  71BqAINEnezjQfxE4VuJfq        41.0        91.0
# 2      2           2  5fp7tsbfsLW8ueAqrvcXOM        41.0        12.0
# 3      3           3  5YLfD5P6wnlAtKG6l4kObB        19.0        47.0
# 4      4           4  3Ei2OxIID6rSuPkvp6dIGP        49.0        57.0
#
#   is_explicit  duration_ms               album_name album_release_date  \
# 0       False     145511.0                     "Se"         2024-01-19
# 1       False     180381.0  1989 (Taylor's Version)         2023-10-26
# 2        True     183003.0                 BENIHANA         2024-03-15
# 3        True     129522.0                        X         2024-03-03
# 4        True     178775.0          #PHONKFREESTYLE         2024-01-26
#
#    time_signature  ...  instrumentalness  liveness speechiness  \
# ...

# %%
df.columns
# Out:
# Index(['index', 'Unnamed: 0', 'spotify_id', 'daily_rank', 'popularity',
#        'is_explicit', 'duration_ms', 'album_name', 'album_release_date',
#        'time_signature', 'rank', 'artists_num', 'artist_individual',
#        'artist_id', 'artist_genre', 'album_num_tracks', 'weeks_on_chart',
#        'duration', 'region', 'language', 'track_name', 'artist_names',
#        'country', 'loudness', 'tempo', 'artist_count_df1', 'bpm_df1',
#        'artist_count_df2', 'streams', 'bpm_df2', 'key', 'mode', 'danceability',
#        'valence', 'energy', 'acousticness', 'instrumentalness', 'liveness',
#        'speechiness', 'release_date', 'has_lyrics', 'lyrics_url', 'lyrics',
#        'scraped', 'primary_artist', 'feat_artist', 'lyric_url'],
#       dtype='object')

# %%
df = df.drop(columns=['index', 'Unnamed: 0', "lyrics_url"])

# %%
df.head(20)
# Out:
#     Unnamed: 0              spotify_id  daily_rank  popularity is_explicit  \
# 0            0  65UgeS6VdIpUQqR3UoGw9j        48.0        54.0       False
# 1            1  71BqAINEnezjQfxE4VuJfq        41.0        91.0       False
# 2            2  5fp7tsbfsLW8ueAqrvcXOM        41.0        12.0        True
# 3            3  5YLfD5P6wnlAtKG6l4kObB        19.0        47.0        True
# 4            4  3Ei2OxIID6rSuPkvp6dIGP        49.0        57.0        True
# 5            5  3bY8hZbtWQpCOGHi1IZvz5        47.0        39.0       False
# 6            6  68cUJFq7aAbgeurngTmngL        50.0        82.0        True
# 7            7  2uGrSoj2G2ttrcGvDSl5Bg        50.0        42.0       False
# 8            8  44muA7zBeipDRXs1uaTNLv        31.0        68.0       False
# 9            9  1DNXCTUHCGcr9kJ6LynYEC        47.0        50.0       False
# 10          10  1GZnoLPpR9p2CwclsZnOXD        50.0        73.0       False
# ...

# %%
df[["spotify_id", "track_name", "artist_names", "language", "scraped"]]
# Out:
#                    spotify_id                                   track_name  \
# 0      65UgeS6VdIpUQqR3UoGw9j                                         "Se"
# 1      71BqAINEnezjQfxE4VuJfq  "Slut!" (Taylor's Version) (From The Vault)
# 2      5fp7tsbfsLW8ueAqrvcXOM                                 "conspiracy"
# 3      5YLfD5P6wnlAtKG6l4kObB                                   #BÂTIMENT1
# 4      3Ei2OxIID6rSuPkvp6dIGP                              #PHONKFREESTYLE
# ...                       ...                                          ...
# 25194  16BS342F89MDqouSxgLaUK                      무제(無題) (Untitled, 2014)
# 25195  2Oc0j4x7HkDRVZq8JsgACT                              별별별 (See that?)
# 25196  6fbS9Lbyv6L4tz7tcmBGKh                              보나마나 (BONAMANA)
# 25197  3HAkoNmThZhyFejhpRXXYI                                          예뻤어
# 25198  0EhdXt3y460mTRsi97Pyk5                                한 페이지가 될 수 있게
#
#                                   artist_names     language  scraped
# ...

# %%
lyrics_url = "https://genius.com/Lany-cause-you-have-to-lyrics"
lyrics = scrape_lyrics(lyrics_url)

# %%
df.loc[df["spotify_id"]=="1GZnoLPpR9p2CwclsZnOXD", "lyrics"] = lyrics
df.loc[df["spotify_id"]=="1GZnoLPpR9p2CwclsZnOXD", "scraped"] = True
df.loc[df["spotify_id"]=="1GZnoLPpR9p2CwclsZnOXD", "language"] = "English"
df.loc[df["spotify_id"]=="1GZnoLPpR9p2CwclsZnOXD", "lyric_url"] = lyrics_url

# %%
df.loc[df["spotify_id"]=="44muA7zBeipDRXs1uaTNLv", "language"] = "Non-English"

# %%
df.to_csv("../data/lyrics_25200.csv")
