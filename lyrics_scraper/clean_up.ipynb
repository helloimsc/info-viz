# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/lyrics_duplicates_removed.csv")

# %%
df = df.reset_index()

# %%
df.head()
# Out:
#    index  Unnamed: 0.1  Unnamed: 0              spotify_id  daily_rank  \
# 0      0             0           0  65UgeS6VdIpUQqR3UoGw9j        48.0
# 1      1             1           1  71BqAINEnezjQfxE4VuJfq        41.0
# 2      2             2           2  5fp7tsbfsLW8ueAqrvcXOM        41.0
# 3      3             3           3  5YLfD5P6wnlAtKG6l4kObB        19.0
# 4      4             4           4  3Ei2OxIID6rSuPkvp6dIGP        49.0
#
#    popularity is_explicit  duration_ms               album_name  \
# 0        54.0       False     145511.0                     "Se"
# 1        91.0       False     180381.0  1989 (Taylor's Version)
# 2        12.0        True     183003.0                 BENIHANA
# 3        47.0        True     129522.0                        X
# 4        57.0        True     178775.0          #PHONKFREESTYLE
#
#   album_release_date  ...  liveness  speechiness      release_date has_lyrics  \
# ...

# %%
df.columns
# Out:
# Index(['index', 'Unnamed: 0.1', 'Unnamed: 0', 'spotify_id', 'daily_rank',
#        'popularity', 'is_explicit', 'duration_ms', 'album_name',
#        'album_release_date', 'time_signature', 'rank', 'artists_num',
#        'artist_individual', 'artist_id', 'artist_genre', 'album_num_tracks',
#        'weeks_on_chart', 'duration', 'region', 'language', 'track_name',
#        'artist_names', 'country', 'loudness', 'tempo', 'artist_count_df1',
#        'bpm_df1', 'artist_count_df2', 'streams', 'bpm_df2', 'key', 'mode',
#        'danceability', 'valence', 'energy', 'acousticness', 'instrumentalness',
#        'liveness', 'speechiness', 'release_date', 'has_lyrics', 'lyrics_url',
#        'lyrics', 'scraped', 'primary_artist', 'feat_artist', 'lyric_url'],
#       dtype='object')

# %%
df = df.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'])

# %%
df.head()
# Out:
#    index              spotify_id  daily_rank  popularity is_explicit  \
# 0      0  65UgeS6VdIpUQqR3UoGw9j        48.0        54.0       False
# 1      1  71BqAINEnezjQfxE4VuJfq        41.0        91.0       False
# 2      2  5fp7tsbfsLW8ueAqrvcXOM        41.0        12.0        True
# 3      3  5YLfD5P6wnlAtKG6l4kObB        19.0        47.0        True
# 4      4  3Ei2OxIID6rSuPkvp6dIGP        49.0        57.0        True
#
#    duration_ms               album_name album_release_date  time_signature  \
# 0     145511.0                     "Se"         2024-01-19             4.0
# 1     180381.0  1989 (Taylor's Version)         2023-10-26             4.0
# 2     183003.0                 BENIHANA         2024-03-15             4.0
# 3     129522.0                        X         2024-03-03             4.0
# 4     178775.0          #PHONKFREESTYLE         2024-01-26             4.0
#
#    rank  ...  liveness speechiness      release_date has_lyrics  lyrics_url  \
# ...

# %%
df = df.drop(columns=["index", "lyrics_url"])

# %%
df.head()
# Out:
#                spotify_id  daily_rank  popularity is_explicit  duration_ms  \
# 0  65UgeS6VdIpUQqR3UoGw9j        48.0        54.0       False     145511.0
# 1  71BqAINEnezjQfxE4VuJfq        41.0        91.0       False     180381.0
# 2  5fp7tsbfsLW8ueAqrvcXOM        41.0        12.0        True     183003.0
# 3  5YLfD5P6wnlAtKG6l4kObB        19.0        47.0        True     129522.0
# 4  3Ei2OxIID6rSuPkvp6dIGP        49.0        57.0        True     178775.0
#
#                 album_name album_release_date  time_signature  rank  \
# 0                     "Se"         2024-01-19             4.0   NaN
# 1  1989 (Taylor's Version)         2023-10-26             4.0   NaN
# 2                 BENIHANA         2024-03-15             4.0   NaN
# 3                        X         2024-03-03             4.0   NaN
# 4          #PHONKFREESTYLE         2024-01-26             4.0   NaN
#
#    artists_num  ... instrumentalness liveness speechiness      release_date  \
# ...

# %%
df_slice = df[df["language"] == "English"].copy()  
df_slice['language'] = None  
df.update(df_slice)

# %%
df.head()
# Out:
#                spotify_id  daily_rank  popularity is_explicit  duration_ms  \
# 0  65UgeS6VdIpUQqR3UoGw9j        48.0        54.0       False     145511.0
# 1  71BqAINEnezjQfxE4VuJfq        41.0        91.0       False     180381.0
# 2  5fp7tsbfsLW8ueAqrvcXOM        41.0        12.0        True     183003.0
# 3  5YLfD5P6wnlAtKG6l4kObB        19.0        47.0        True     129522.0
# 4  3Ei2OxIID6rSuPkvp6dIGP        49.0        57.0        True     178775.0
#
#                 album_name album_release_date  time_signature  rank  \
# 0                     "Se"         2024-01-19             4.0   NaN
# 1  1989 (Taylor's Version)         2023-10-26             4.0   NaN
# 2                 BENIHANA         2024-03-15             4.0   NaN
# 3                        X         2024-03-03             4.0   NaN
# 4          #PHONKFREESTYLE         2024-01-26             4.0   NaN
#
#    artists_num  ... instrumentalness liveness speechiness      release_date  \
# ...

# %%
df.to_csv("../lyrics_updated_language_from_bottom.csv")
