# %%
import pandas as pd

# %%
df = pd.read_pickle("../data/ver2_w_lyrics_features.p")

# %%
df.head()
# Out:
#    Unnamed: 0              spotify_id  daily_rank  popularity  is_explicit  \
# 0           1  71BqAINEnezjQfxE4VuJfq        41.0        91.0          0.0
# 1           2  5fp7tsbfsLW8ueAqrvcXOM        41.0        12.0          1.0
# 2           9  1DNXCTUHCGcr9kJ6LynYEC        47.0        50.0          0.0
# 3          11  4k3lPl8YTKuY8c1HelVnm3         NaN         NaN          NaN
# 4          13  2qWvKCmXuL7LJyEhm8lRH3        13.0        32.0          0.0
#
#    duration_ms                      album_name album_release_date  \
# 0     180381.0         1989 (Taylor's Version)         2023-10-26
# 1     183003.0                        BENIHANA         2024-03-15
# 2     250595.0                a beautiful blur         2023-09-29
# 3          NaN                             NaN                NaT
# 4     145000.0  (Can't) Get You out of My Mind         2019-09-03
#
#    time_signature  rank  ...  \
# 0             4.0   NaN  ...
# 1             4.0   NaN  ...
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'spotify_id', 'daily_rank', 'popularity', 'is_explicit',
#        'duration_ms', 'album_name', 'album_release_date', 'time_signature',
#        'rank', 'artists_num', 'artist_individual', 'artist_id', 'artist_genre',
#        'album_num_tracks', 'weeks_on_chart', 'duration', 'region', 'language',
#        'track_name', 'artist_names', 'country', 'loudness', 'tempo',
#        'artist_count_df1', 'bpm_df1', 'artist_count_df2', 'streams', 'bpm_df2',
#        'key', 'mode', 'danceability', 'valence', 'energy', 'acousticness',
#        'instrumentalness', 'liveness', 'speechiness', 'release_date',
#        'has_lyrics', 'lyrics_url', 'lyrics', 'scraped', 'primary_artist',
#        'feat_artist', 'lyric_url', 'is_english', 'is_english_lyrics',
#        'lyrics_sections', 'sentiments_raw', 'sentiments', 'overall_sentiments',
#        'emotions_raw', 'emotions', 'overall_emotions', 'topics_raw', 'topics',
#        'overall_topics'],
#       dtype='object')

# %%
columns_to_drop = ["Unnamed: 0", "lyrics", "topics_raw", "emotions", "emotions_raw", "sentiments", "sentiments_raw", "lyrics_sections",]

# %%
df = df.drop(columns=columns_to_drop)

# %%
df.head()
# Out:
#                spotify_id  daily_rank  popularity  is_explicit  duration_ms  \
# 0  71BqAINEnezjQfxE4VuJfq        41.0        91.0          0.0     180381.0
# 1  5fp7tsbfsLW8ueAqrvcXOM        41.0        12.0          1.0     183003.0
# 2  1DNXCTUHCGcr9kJ6LynYEC        47.0        50.0          0.0     250595.0
# 3  4k3lPl8YTKuY8c1HelVnm3         NaN         NaN          NaN          NaN
# 4  2qWvKCmXuL7LJyEhm8lRH3        13.0        32.0          0.0     145000.0
#
#                        album_name album_release_date  time_signature  rank  \
# 0         1989 (Taylor's Version)         2023-10-26             4.0   NaN
# 1                        BENIHANA         2024-03-15             4.0   NaN
# 2                a beautiful blur         2023-09-29             3.0   NaN
# 3                             NaN                NaT             NaN  68.0
# 4  (Can't) Get You out of My Mind         2019-09-03             4.0   NaN
#
#    artists_num  ... scraped primary_artist feat_artist  \
# ...

# %%
df.to_csv("../data/for_vis.csv")
